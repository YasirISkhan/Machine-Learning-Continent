# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

querystring = {"lat":"35.5","lon":"-78.5","units":"imperial","lang":"en"}

headers = {
	"x-rapidapi-key": "131c1e54c9msh70a551e28d52be0p147b6ejsn9d8a2afac24c",
	"x-rapidapi-host": "weatherbit-v1-mashape.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'dewpt': 29.7, 'uv': 6, 'wind_dir': 290, 'ghi': 749, 'dhi': 114, 'precip': 0, 'weather': {'description': 'Clear Sky', 'code': 800, 'icon': 'c01d'}, 'temp': 60.4, 'app_temp': 60.4, 'timestamp_local': '2025-02-28T13:00:00', 'clouds_mid': 0, 'pop': 0, 'ozone': 340, 'clouds_hi': 0, 'wind_cdir': 'WNW', 'rh': 31, 'pod': 'd', 'wind_gust_spd': 12.3, 'pres': 1005, 'timestamp_utc': '2025-02-28T18:00:00', 'snow_depth': 0, 'clouds_low': 0, 'clouds': 1, 'vis': 14.9, 'dni': 897, 'wind_spd': 7.2, 'solar_rad': 749.3399, 'wind_cdir_full': 'west-northwest', 'slp': 1013, 'datetime': '2025-02-28:18', 'ts': 1740765600, 'snow': 0}, {'dewpt': 28.6, 'uv': 2, 'wind_dir': 240, 'ghi': 371, 'dhi': 85, 'precip': 0, 'weather': {'description': 'Clear Sky', 'code': 800, 'icon': 'c01d'}, 'temp': 63.1, 'app_temp': 63.1, 'timestamp_local': '2025-02-28T16:00:00', 'clouds_mid': 0, 'pop': 0, 'ozone': 341, 'clouds_hi': 0, 'wind_cdir': 'WSW', 'rh': 27, 'pod': 'd', 'wind_gust_spd': 10.1, 'pres': 1003, 'timestamp_
# ...

# %%
df = pd.DataFrame(response.json()['data'])

# %%
df.head()
# Out:
#    dewpt  uv  wind_dir  ghi  dhi  precip  \
# 0   29.7   6       290  749  114     0.0
# 1   28.6   2       240  371   85     0.0
# 2   32.0   0       210    0    0     0.0
# 3   34.5   0       200    0    0     0.0
# 4   34.3   0       210    0    0     0.0
#
#                                              weather  temp  app_temp  \
# 0  {'description': 'Clear Sky', 'code': 800, 'ico...  60.4      60.4
# 1  {'description': 'Clear Sky', 'code': 800, 'ico...  63.1      63.1
# 2  {'description': 'Clear Sky', 'code': 800, 'ico...  54.7      54.7
# 3  {'description': 'Few clouds', 'code': 801, 'ic...  50.0      50.0
# 4  {'description': 'Few clouds', 'code': 801, 'ic...  48.4      48.4
#
#        timestamp_local  ...  clouds   vis  dni  wind_spd  solar_rad  \
# 0  2025-02-28T13:00:00  ...       1  14.9  897       7.2  749.33990
# 1  2025-02-28T16:00:00  ...       1  14.9  732       5.4  371.07993
# 2  2025-02-28T19:00:00  ...       1  14.9    0       2.7    0.00000
# ...

# %%
url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/daily"

querystring = {"lat":"38.5","lon":"-78.5","units":"imperial","lang":"en"}

headers = {
	"x-rapidapi-key": "131c1e54c9msh70a551e28d52be0p147b6ejsn9d8a2afac24c",
	"x-rapidapi-host": "weatherbit-v1-mashape.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'city_name': 'Stanley', 'country_code': 'US', 'data': [{'app_max_temp': 48.7, 'app_min_temp': 24.8, 'clouds': 15, 'clouds_hi': 1, 'clouds_low': 1, 'clouds_mid': 0, 'datetime': '2025-02-28', 'dewpt': 23.9, 'high_temp': 49.8, 'low_temp': 40.6, 'max_dhi': None, 'max_temp': 49.8, 'min_temp': 32.4, 'moon_phase': 0.01, 'moon_phase_lunation': 0.03, 'moonrise_ts': 1740744750, 'moonset_ts': 1740787629, 'ozone': 355, 'pop': 0, 'precip': 0, 'pres': 931, 'rh': 51, 'slp': 1007, 'snow': 0, 'snow_depth': 0, 'sunrise_ts': 1740743205, 'sunset_ts': 1740784059, 'temp': 41.5, 'ts': 1740718860, 'uv': 5, 'valid_date': '2025-02-28', 'vis': 14.9, 'weather': {'code': 801, 'icon': 'c02d', 'description': 'Few clouds'}, 'wind_cdir': 'W', 'wind_cdir_full': 'west', 'wind_dir': 260, 'wind_gust_spd': 22.4, 'wind_spd': 13.2}, {'app_max_temp': 46.4, 'app_min_temp': 11.3, 'clouds': 28, 'clouds_hi': 0, 'clouds_low': 31, 'clouds_mid': 0, 'datetime': '2025-03-01', 'dewpt': 23, 'high_temp': 48, 'low_temp': 17.6, 'max_dhi
# ...

# %%
df2 = pd.DataFrame(response.json()['data'])

# %%
df = pd.concat([df, df2], ignore_index=True)

# %%
df
# Out:
#     dewpt  uv  wind_dir    ghi    dhi  precip  \
# 0    29.7   6       290  749.0  114.0   0.000
# 1    28.6   2       240  371.0   85.0   0.000
# 2    32.0   0       210    0.0    0.0   0.000
# 3    34.5   0       200    0.0    0.0   0.000
# 4    34.3   0       210    0.0    0.0   0.000
# 5    34.5   0       220    0.0    0.0   0.000
# 6    35.4   1       220   22.0   23.0   0.000
# 7    40.3   4       240  577.0  103.0   0.000
# 8    40.3   5       250  760.0  114.0   0.000
# 9    37.8   2       270  379.0   86.0   0.000
# 10   33.8   0       330    0.0    0.0   0.000
# 11   26.6   0       350    0.0    0.0   0.000
# 12   18.9   0       350    0.0    0.0   0.000
# 13   16.0   0       350    0.0    0.0   0.000
# 14   15.3   1       360   25.0   25.0   0.000
# 15   13.6   4         0  583.0  103.0   0.000
# 16   12.6   6       350  765.0  115.0   0.000
# 17   12.4   2       330  383.0   87.0   0.000
# 18   16.0   0       360    0.0    0.0   0.000
# ...

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://cdn.jsdelivr.net/gh/fawazahmed0/quran-api@1/info.json')

# %%
df = pd.DataFrame(response.json()['chapters'])

# %%
df.head(2)
# Out:
#    chapter        name  englishname             arabicname revelation  \
# 0        1  Al-Faatiha  The Opening  سُوْرَةُ الْفَاتِحَةِ      Mecca
# 1        2   Al-Baqara      The Cow    سُوْرَةُ البَقَرَةِ     Madina
#
#                                               verses
# 0  [{'verse': 1, 'line': 1, 'juz': 1, 'manzil': 1...
# 1  [{'verse': 1, 'line': 8, 'juz': 1, 'manzil': 1...

# %%
df['verses'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 114 entries, 0 to 113
# Series name: verses
# Non-Null Count  Dtype
# --------------  -----
# 114 non-null    object
# dtypes: object(1)
# memory usage: 1.0+ KB

# %%
df.to_csv('Quran.csv')
