# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Finding details
print('Mean value of cgpa', df['cgpa'].mean())
print('Std value of cgpa', df['cgpa'].std())
print('Min value of cgpa', df['cgpa'].min())
print('Max value of cgpa', df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323894
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
# Finding the boundary values
print('Highest allowed', df['cgpa'].mean() + 3*df['cgpa'].std())
print('Lowest allowed', df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
# Trimming
new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df.shape
# Out:
# (995, 3)

# %%
# Approach 2

# %%
# Capping
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
df['cgpa'] = np.where(df['cgpa'] > upper_limit, upper_limit, np.where(df['cgpa'] < lower_limit, lower_limit, df['cgpa']))

# %%
df['cgpa'].shape
# Out:
# (1000,)

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64

# %% [markdown]
# # Practice

# %%
data = pd.read_csv('Fraud_Detection.csv', usecols=['Transaction_Amount','Account_Age','Fraudulent'])

# %%
data.head()
# Out:
#    Transaction_Amount  Account_Age  Fraudulent
# 0             1292.76          119           0
# 1             1554.58           79           0
# 2             2395.02          115           0
# 3              100.10            3           0
# 4             1490.50           57           0

# %%
data.shape
# Out:
# (51000, 3)

# %%
data.describe()
# Out:
#        Transaction_Amount   Account_Age    Fraudulent
# count        48480.000000  51000.000000  51000.000000
# mean          2996.249784     60.033902      0.049216
# std           5043.932555     34.384131      0.216320
# min              5.030000      1.000000      0.000000
# 25%           1270.552500     30.000000      0.000000
# 50%           2524.100000     60.000000      0.000000
# 75%           3787.240000     90.000000      0.000000
# max          49997.800000    119.000000      1.000000

# %%
# 1. Outlier Detection using Z-score method
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(data['Transaction_Amount'])

plt.subplot(1,2,2)
sns.distplot(data['Account_Age'])
plt.show()
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\1798523059.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Transaction_Amount'])
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\1798523059.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 2. Finding details
print('The Mean of Transaction_Amount', data['Transaction_Amount'].mean())
print('The Std of Transaction_Amount', data['Transaction_Amount'].std())
print('The Min Value of Transaction_Amount', data['Transaction_Amount'].min())
print('The Max value of Transaction_Amount', data['Transaction_Amount'].max())
# Out:
# The Mean of Transaction_Amount 2996.249784447195
# The Std of Transaction_Amount 5043.93255475391
# The Min Value of Transaction_Amount 5.03
# The Max value of Transaction_Amount 49997.8

# %%
print('Upper boundary of Transaction_Amount', data['Transaction_Amount'].mean() + 3*data['Transaction_Amount'].std())
print('Lower boundary of Transaction_Amount', data['Transaction_Amount'].mean() - 3*data['Transaction_Amount'].std())
# Out:
# Upper boundary of Transaction_Amount 18128.047448708927
# Lower boundary of Transaction_Amount -12135.547879814536

# %%
# Finding outliers

data[(data['Transaction_Amount'] > 18128) | (data['Transaction_Amount'] < -12135)]
# Out:
#        Transaction_Amount  Account_Age  Fraudulent
# 166               49997.8          108           0
# 236               49997.8          103           0
# 245               49997.8           78           0
# 298               49997.8           85           0
# 317               49997.8            4           0
# ...                   ...          ...         ...
# 50570             49997.8           91           0
# 50597             49997.8           43           1
# 50705             49997.8           22           0
# 50863             49997.8           44           0
# 50945             49997.8           82           0
#
# [508 rows x 3 columns]

# %%
# Trimming
new_data = data[(data['Transaction_Amount'] < 18128) & (data['Transaction_Amount']> -12135)]

# %%
new_data.shape
# Out:
# (47972, 3)

# %%
# Capping

# %%
# Calculating upper and lower limit
upper_limit = (data['Transaction_Amount'].mean() + 3*data['Transaction_Amount'].std())
lower_limit = (data['Transaction_Amount'].mean() - 3*data['Transaction_Amount'].std())

# %%
upper_limit
lower_limit
# Out:
# -12135.547879814536

# %%
data['Transaction_Amount'] = np.where(data['Transaction_Amount'] > upper_limit, upper_limit, np.where(data['Transaction_Amount'] < lower_limit, lower_limit, data['Transaction_Amount']))

# %%
data.describe()
# Out:
#        Transaction_Amount   Account_Age    Fraudulent
# count        48480.000000  51000.000000  51000.000000
# mean          2662.301057     60.033902      0.049216
# std           2140.082034     34.384131      0.216320
# min              5.030000      1.000000      0.000000
# 25%           1270.552500     30.000000      0.000000
# 50%           2524.100000     60.000000      0.000000
# 75%           3787.240000     90.000000      0.000000
# max          18128.047449    119.000000      1.000000

# %% [markdown]
# # Practice 2

# %%
dframe = pd.read_csv('student_admission.csv', usecols=['Age','Admission Test Score','High School Percentage','Admission Status'])

# %%
dframe.shape
# Out:
# (157, 4)

# %%
dframe.head()
# Out:
#     Age  Admission Test Score  High School Percentage Admission Status
# 0  24.0                  50.0                   68.90         Rejected
# 1  21.0                  99.0                   60.73              NaN
# 2  17.0                  89.0                     NaN         Accepted
# 3  17.0                  55.0                   85.29         Rejected
# 4  20.0                  65.0                   61.13              NaN

# %%
# Outlier treatment using Z-score technique
# Assumption is that data should be normally distributed
# Checking distribution of data

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.distplot(dframe['Age'])

plt.subplot(1,2,2)
sns.distplot(dframe['Admission Test Score'])

plt.subplot(1,2,3)
sns.distplot(dframe['High School Percentage'])

plt.show()
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\1378794991.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dframe['Age'])
# C:\Users\yasir\AppData\Local\Temp\ipykernel_14932\1378794991.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Finding Details of the column
print('The Mean of the Age, ', dframe['Age'].mean())
print('The Std of the Age', dframe['Age'].std())
print('The Min Value of the Age', dframe['Age'].min())
print('The Max Value of the Age', dframe['Age'].max())
# Out:
# The Mean of the Age,  19.68027210884354
# The Std of the Age 4.540512303721261
# The Min Value of the Age -1.0
# The Max Value of the Age 24.0

# %%
# Finding out the records that are outliers
upper_limit = (dframe['Age'].mean() + 3*dframe['Age'].std())
lower_limit = (dframe['Age'].mean() - 3*dframe['Age'].std())

print(upper_limit)
print(lower_limit)
# Out:
# 33.301809020007326
# 6.058735197679756

# %%
new_dframe = dframe[((dframe['Age'] > 33) | (dframe['Age'] < 6))]
new_dframe
# Out:
#      Age  Admission Test Score  High School Percentage Admission Status
# 23  -1.0                 101.0                   54.59              NaN
# 50  -1.0                  61.0                   69.48         Rejected
# 89  -1.0                  66.0                   79.07         Rejected
# 113 -1.0                  84.0                   58.77         Rejected
# 155 -1.0                  91.0                   80.12         Accepted

# %%
# Trimming
new_dframe = dframe[(dframe['Age'] < 33) & (dframe['Age'] > 6)]

# %%
new_dframe.describe()
# Out:
#               Age  Admission Test Score  High School Percentage
# count  142.000000            131.000000              131.000000
# mean    20.408451             77.305344               75.704656
# std      2.376465             17.161179               17.907736
# min     17.000000             -5.000000              -10.000000
# 25%     18.000000             68.500000               64.290000
# 50%     20.000000             78.000000               77.690000
# 75%     22.750000             89.000000               89.555000
# max     24.000000            150.000000              110.500000

# %%
new_dframe.shape
# Out:
# (142, 4)

# %%
# Capping
new_dframe = np.where(dframe['Age'] > upper_limit, upper_limit, np.where(dframe['Age'] < lower_limit, lower_limit, dframe['Age']) )

# %%
new_dframe.shape
# Out:
# (157,)
