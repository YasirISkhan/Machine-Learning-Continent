# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 405          406         0       2            Gale, Mr. Shadrach    male
# 516          517         1       2  Lemore, Mrs. (Amelia Milley)  female
# 616          617         0       3     Danbom, Mr. Ernst Gilbert    male
#
#       Age  SibSp  Parch      Ticket  Fare Cabin Embarked
# 405  34.0      1      0       28664  21.0   NaN        S
# 516  34.0      0      0  C.A. 34260  10.5   F33        S
# 616  34.0      1      1      347080  14.4   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# # Countplot()

# %%
sns.countplot(data=df, x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# # Piechart

# %%
df['Survived'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# # 1. Histogram

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'], bins=50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist(df['Fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SibSp'])
# Out:
# (array([608., 209.,  28.,  16.,   0.,  18.,   5.,   0.,   0.,   7.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_13464\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['SibSp'])
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_13464\1634579339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SibSp'])
# <Axes: xlabel='SibSp', ylabel='Density'>

# %% [markdown]
# # c. Boxplot

# %%
sns.boxplot(data=df, x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(data=df, x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# # Univariate Analysis-Practice

# %%
df = pd.read_csv('Quran-Dataset.csv', index_col='Unnamed: 0')

# %%
df.head()
# Out:
#    chapter          name           englishname              arabicname  \
# 0        1    Al-Faatiha           The Opening   سُوْرَةُ الْفَاتِحَةِ
# 1        2     Al-Baqara               The Cow     سُوْرَةُ البَقَرَةِ
# 2        3  Aal-i-Imraan  The Family of Imraan  سُوْرَةُ اٰلِ عِمْرٰنَ
# 3        4      An-Nisaa             The Women    سُوْرَةُ النِّسَآءِ
# 4        5     Al-Maaida             The Table   سُوْرَةُ المَآئِدَةِ
#
#   revelation                                             verses
# 0      Mecca  [{'verse': 1, 'line': 1, 'juz': 1, 'manzil': 1...
# 1     Madina  [{'verse': 1, 'line': 8, 'juz': 1, 'manzil': 1...
# 2     Madina  [{'verse': 1, 'line': 294, 'juz': 3, 'manzil':...
# 3     Madina  [{'verse': 1, 'line': 494, 'juz': 4, 'manzil':...
# 4     Madina  [{'verse': 1, 'line': 670, 'juz': 6, 'manzil':...

# %%
#. Categorical Data
# countplot
sns.countplot(data=df, x=df['revelation'])
# Out:
# <Axes: xlabel='revelation', ylabel='count'>

# %%
df['revelation'].value_counts()
# Out:
# revelation
# Mecca     86
# Madina    28
# Name: count, dtype: int64

# %%
df['revelation'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# dataset
df = pd.read_csv('Charging-Stations.csv', low_memory=False)

# %%
df.head()
# Out:
#           time alarmtimer_alarmtimer_cancel alarmtimer_alarmtimer_fired  \
# 0  5.001476508                            0                           0
# 1  5.001487254                            0                           0
# 2  5.001640501                            0                           0
# 3  5.003761639                            0                           0
# 4  10.06573989                            0                           0
#
#   alarmtimer_alarmtimer_start alarmtimer_alarmtimer_suspend alignment-faults  \
# 0                           0                             0                0
# 1                           0                             0                0
# 2                           0                             0                0
# 3                           0                             0                0
# 4                           0                             0                0
#
#     ase_spec block_block_bio_backmerge block_block_bio_bounce  \
# ...

# %%
sns.countplot(df['State'])
# Out:
# <Axes: xlabel='count', ylabel='State'>

# %%
df['State'].value_counts()
# Out:
# State
# Charging                               3584
# idle                                   2582
# 0                                      2302
# writeback:writeback_wake_background       1
# Name: count, dtype: int64

# %%
df['State'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['Attack'])
# Out:
# <Axes: xlabel='count', ylabel='Attack'>

# %%
df['Attack'].value_counts()
# Out:
# Attack
# 0                                  2302
# none                               2302
# cryptojacking                      1793
# port-scan                           201
# vuln-scan                           192
# syn-stealth                         189
# aggressive-scan                     182
# service-detection                   139
# icmp-flood                          128
# push-ack-flood                      127
# syn-flood                           126
# os-fingerprinting                   123
# tcp-flood                           123
# synonymous-ip-flood                 122
# udp-flood                           120
# icmp-fragmentation                  119
# icmp-fragmentation_old               61
# serice-detection                     60
# os-scan                              59
# writeback:writeback_write_inode       1
# Name: count, dtype: int64

# %%
sns.countplot(df['Label'])
# Out:
# <Axes: xlabel='count', ylabel='Label'>

# %%
df['Label'].value_counts()
# Out:
# Label
# attack                         3864
# benign                         2302
# 0                              2302
# writeback:writeback_written       1
# Name: count, dtype: int64

# %%
df['Label'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>
