# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mobiles-Dataset.csv', encoding='latin-1')

# %%
df.head(3)
# Out:
#   Company Name       Model Name Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB          174g  6GB         12MP        48MP
# 1        Apple  iPhone 16 256GB          174g  6GB         12MP        48MP
# 2        Apple  iPhone 16 512GB          174g  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0  A17 Bionic         3,600mAh  6.1 inches               PKR 224,999
# 1  A17 Bionic         3,600mAh  6.1 inches               PKR 234,999
# 2  A17 Bionic         3,600mAh  6.1 inches               PKR 244,999
#
#   Launched Price (India) Launched Price (China) Launched Price (USA)  \
# 0             INR 79,999              CNY 5,799              USD 799
# 1             INR 84,999              CNY 6,099              USD 849
# 2             INR 89,999              CNY 6,499              USD 899
#
#   Launched Price (Dubai)  Launched Year
# 0              AED 2,799           2024
# ...

# %%
# Data Understanding
# 1. Size of data
df.shape
# Out:
# (930, 15)

# %%
# 2. Structure of the data
df.sample(5)
# Out:
#     Company Name         Model Name Mobile Weight  RAM Front Camera  \
# 755      Infinix         Hot 50 Pro          194g  8GB         16MP
# 874        Honor      Tablet V7 Pro          485g  8GB          8MP
# 780      Infinix  Hot 12 Play 128GB          209g  4GB          8MP
# 594     Motorola     Moto G45 128GB          183g  6GB         16MP
# 899         POCO           F3 128GB          196g  6GB         20MP
#
#     Back Camera                 Processor Battery Capacity  Screen Size  \
# 755        50MP        MediaTek Helio G99         5,000mAh   6.8 inches
# 874        13MP  MediaTek Dimensity 1300T         7,250mAh  11.0 inches
# 780        13MP               Unisoc T610         6,000mAh  6.82 inches
# 594        50MP       Snapdragon 6s Gen 3         5,000mAh   6.5 inches
# 899        48MP            Snapdragon 870          4520mAh  6.67 inches
#
#     Launched Price (Pakistan) Launched Price (India) Launched Price (China)  \
# ...

# %%
# 3. Datatype of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    object
#  10  Launched Price (India)     930 non-null    object
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
# 4. Mathematical representation of the data
df.describe()
# Out:
#        Launched Year
# count     930.000000
# mean     2022.193548
# std         1.862080
# min      2014.000000
# 25%      2021.000000
# 50%      2023.000000
# 75%      2024.000000
# max      2025.000000

# %%
# 5. Null values in the dataset
df.isnull().sum()
# Out:
# Company Name                 0
# Model Name                   0
# Mobile Weight                0
# RAM                          0
# Front Camera                 0
# Back Camera                  0
# Processor                    0
# Battery Capacity             0
# Screen Size                  0
# Launched Price (Pakistan)    0
# Launched Price (India)       0
# Launched Price (China)       0
# Launched Price (USA)         0
# Launched Price (Dubai)       0
# Launched Year                0
# dtype: int64

# %%
# 6. duplicate values
df.duplicated().sum()
# Out:
# 15

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file = 'output.html')
# Out:
# KeyboardInterrupt

# %%
# Handling mixed variables
df.head(2)
# Out:
#   Company Name       Model Name Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB          174g  6GB         12MP        48MP
# 1        Apple  iPhone 16 256GB          174g  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0  A17 Bionic         3,600mAh  6.1 inches               PKR 224,999
# 1  A17 Bionic         3,600mAh  6.1 inches               PKR 234,999
#
#   Launched Price (India) Launched Price (China) Launched Price (USA)  \
# 0             INR 79,999              CNY 5,799              USD 799
# 1             INR 84,999              CNY 6,099              USD 849
#
#   Launched Price (Dubai)  Launched Year
# 0              AED 2,799           2024
# 1              AED 2,999           2024

# %%
df['Mobile Weight'] = df['Mobile Weight'].str.extract(r'(\d+\.\d+|\d+)')
df.head(3)
# Out:
#   Company Name       Model Name Mobile Weight  RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB           174  6GB         12MP        48MP
# 1        Apple  iPhone 16 256GB           174  6GB         12MP        48MP
# 2        Apple  iPhone 16 512GB           174  6GB         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0  A17 Bionic         3,600mAh  6.1 inches               PKR 224,999
# 1  A17 Bionic         3,600mAh  6.1 inches               PKR 234,999
# 2  A17 Bionic         3,600mAh  6.1 inches               PKR 244,999
#
#   Launched Price (India) Launched Price (China) Launched Price (USA)  \
# 0             INR 79,999              CNY 5,799              USD 799
# 1             INR 84,999              CNY 6,099              USD 849
# 2             INR 89,999              CNY 6,499              USD 899
#
#   Launched Price (Dubai)  Launched Year
# 0              AED 2,799           2024
# ...

# %%
df['RAM'] = df['RAM'].str.extract(r'(\d+\.\d+|\d+)')

# %%
df.head(3)
# Out:
#   Company Name       Model Name Mobile Weight RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB           174   6         12MP        48MP
# 1        Apple  iPhone 16 256GB           174   6         12MP        48MP
# 2        Apple  iPhone 16 512GB           174   6         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0  A17 Bionic         3,600mAh  6.1 inches               PKR 224,999
# 1  A17 Bionic         3,600mAh  6.1 inches               PKR 234,999
# 2  A17 Bionic         3,600mAh  6.1 inches               PKR 244,999
#
#   Launched Price (India) Launched Price (China) Launched Price (USA)  \
# 0             INR 79,999              CNY 5,799              USD 799
# 1             INR 84,999              CNY 6,099              USD 849
# 2             INR 89,999              CNY 6,499              USD 899
#
#   Launched Price (Dubai)  Launched Year
# 0              AED 2,799           2024
# ...

# %%
df['Launched Price (Pakistan)'] = df['Launched Price (Pakistan)'].str.extract(r'([\d,]+\.\d+|[\d,]+)')
df['Launched Price (India)'] = df['Launched Price (India)'].str.extract(r'([\d,]+\.\d+|[\d,]+)')
df['Launched Price (China)'] = df['Launched Price (China)'].str.extract(r'([\d,]+\.\d+|[\d,]+)')
df['Launched Price (USA)'] = df['Launched Price (USA)'].str.extract(r'([\d,]+\.\d+|[\d,]+)')
df['Launched Price (Dubai)'] = df['Launched Price (Dubai)'].str.extract(r'([\d,]+\.\d+|[\d,]+)')

# %%
df.head(3)
# Out:
#   Company Name       Model Name Mobile Weight RAM Front Camera Back Camera  \
# 0        Apple  iPhone 16 128GB           174   6         12MP        48MP
# 1        Apple  iPhone 16 256GB           174   6         12MP        48MP
# 2        Apple  iPhone 16 512GB           174   6         12MP        48MP
#
#     Processor Battery Capacity Screen Size Launched Price (Pakistan)  \
# 0  A17 Bionic         3,600mAh  6.1 inches                   224,999
# 1  A17 Bionic         3,600mAh  6.1 inches                   234,999
# 2  A17 Bionic         3,600mAh  6.1 inches                   244,999
#
#   Launched Price (India) Launched Price (China) Launched Price (USA)  \
# 0                 79,999                  5,799                  799
# 1                 84,999                  6,099                  849
# 2                 89,999                  6,499                  899
#
#   Launched Price (Dubai)  Launched Year
# 0                  2,799           2024
# ...

# %%
df = df[['Mobile Weight', 'RAM', 'Launched Price (Pakistan)' , 'Launched Price (India)', 'Launched Price (USA)']]

# %%
df.head()
# Out:
#   Mobile Weight RAM Launched Price (Pakistan) Launched Price (India)  \
# 0           174   6                   224,999                 79,999
# 1           174   6                   234,999                 84,999
# 2           174   6                   244,999                 89,999
# 3           203   6                   249,999                 89,999
# 4           203   6                   259,999                 94,999
#
#   Launched Price (USA)
# 0                  799
# 1                  849
# 2                  899
# 3                  899
# 4                  949
