# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.tree import plot_tree

# %%
X, y = make_classification(n_features=5, n_informative=5, n_redundant=0, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X, columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  3.500842 -1.831961  2.504862 -1.101169 -3.410659       1
# 1 -0.009404  1.717036  1.257004  2.332134 -0.613910       1
# 2 -0.003903  1.739238  0.905730  1.971150 -2.689439       1
# 3 -3.205411  2.351561 -2.651634  3.438879 -0.021310       0
# 4  0.446972  0.038495  0.845864 -0.067011 -0.131447       0

# %% [markdown]
# # Function for Feature Sampling

# %%
def feature_sample(df, percent):
    cols = random.sample(df.columns.tolist()[:-1], int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
df1= feature_sample(df, 0.8)
df1
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_15992\3218617853.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
#         col5      col1      col4      col3  target
# 0  -3.410659  3.500842 -1.101169  2.504862       1
# 1  -0.613910 -0.009404  2.332134  1.257004       1
# 2  -2.689439 -0.003903  1.971150  0.905730       1
# 3  -0.021310 -3.205411  3.438879 -2.651634       0
# 4  -0.131447  0.446972 -0.067011  0.845864       0
# ..       ...       ...       ...       ...     ...
# 95 -0.669716  0.597744  0.203561  0.507355       1
# 96 -0.483575  1.883888  0.827472  1.093761       1
# 97  2.209866 -0.894830  0.541444 -1.469262       0
# 98 -1.639762  0.979879  2.384610  1.572592       1
# ...

# %%
df2 = feature_sample(df, 0.8)
df2
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_15992\3218617853.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
#         col2      col1      col4      col3  target
# 0  -1.831961  3.500842 -1.101169  2.504862       1
# 1   1.717036 -0.009404  2.332134  1.257004       1
# 2   1.739238 -0.003903  1.971150  0.905730       1
# 3   2.351561 -3.205411  3.438879 -2.651634       0
# 4   0.038495  0.446972 -0.067011  0.845864       0
# ..       ...       ...       ...       ...     ...
# 95  0.700263  0.597744  0.203561  0.507355       1
# 96  0.279093  1.883888  0.827472  1.093761       1
# 97 -3.646893 -0.894830  0.541444 -1.469262       0
# 98  0.484123  0.979879  2.384610  1.572592       1
# ...

# %%
df3 = feature_sample(df, 0.8)
df3
# Out:
# C:\Users\yasir\AppData\Local\Temp\ipykernel_15992\3218617853.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
#         col3      col1      col2      col5  target
# 0   2.504862  3.500842 -1.831961 -3.410659       1
# 1   1.257004 -0.009404  1.717036 -0.613910       1
# 2   0.905730 -0.003903  1.739238 -2.689439       1
# 3  -2.651634 -3.205411  2.351561 -0.021310       0
# 4   0.845864  0.446972  0.038495 -0.131447       0
# ..       ...       ...       ...       ...     ...
# 95  0.507355  0.597744  0.700263 -0.669716       1
# 96  1.093761  1.883888  0.279093 -0.483575       1
# 97 -1.469262 -0.894830 -3.646893  2.209866       0
# 98  1.572592  0.979879  0.484123 -1.639762       1
# ...

# %%
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:4], df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:4], df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:4], df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.4230769230769231, 0.9, 'x[3] <= 0.286\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.15384615384615385, 0.7, 'x[0] <= -0.964\ngini = 0.201\nsamples = 53\nvalue = [47, 6]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.23076923076923078, 0.5, 'x[0] <= -0.066\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.15384615384615385, 0.3, 'x[2] <= 1.832\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07692307692307693, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23076923076923078, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3076923076923077, 0.3, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(0.6923076923076923, 0.7, 'x[0] <= 1.122\ngini = 0.081\nsamples = 47\nvalue = [2, 45]'),
#  Text(0.5384615384615384, 0.5, 'x[0] <= -0.159\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
#  Text(0.46153846153846156, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.286\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.3076923076923077, 0.75, 'x[1] <= 0.653\ngini = 0.201\nsamples = 53\nvalue = [47, 6]'),
#  Text(0.23076923076923078, 0.5833333333333334, 'x[0] <= 2.743\ngini = 0.113\nsamples = 50\nvalue = [47, 3]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[0] <= 0.778\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(0.23076923076923078, 0.25, 'x[0] <= 0.859\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.15384615384615385, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3076923076923077, 0.08333333333333333, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3076923076923077, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.38461538461538464, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.4230769230769231, 0.9, 'x[0] <= 0.286\ngini = 0.5\nsamples = 100\nvalue = [49, 51]'),
#  Text(0.15384615384615385, 0.7, 'x[3] <= -0.964\ngini = 0.201\nsamples = 53\nvalue = [47, 6]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.23076923076923078, 0.5, 'x[3] <= -0.066\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.15384615384615385, 0.3, 'x[2] <= 1.236\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07692307692307693, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23076923076923078, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3076923076923077, 0.3, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(0.6923076923076923, 0.7, 'x[3] <= 1.122\ngini = 0.081\nsamples = 47\nvalue = [2, 45]'),
#  Text(0.5384615384615384, 0.5, 'x[3] <= -0.159\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
#  Text(0.46153846153846156, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
# ...

# %%
clf1.predict(np.array([-3.410659,	3.500842,	-1.101169,	2.504862]).reshape(1,4))
# Out:
# C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-3.410659,	3.500842,	-1.101169,	2.504862]).reshape(1,4))
# Out:
# C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([-3.410659,	3.500842,	-1.101169,	2.504862]).reshape(1,4))
# Out:
# C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
