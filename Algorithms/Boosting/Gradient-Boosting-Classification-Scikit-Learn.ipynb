# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('Iris.csv')

# %%
df.drop(columns=['Id'], inplace=True)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
target = df['Species']
df.drop(columns=['Species'], inplace=True)
le = LabelEncoder()
target = le.fit_transform(target)

target = pd.DataFrame(target, columns=['Species'])
target
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
df = pd.concat((df, target), axis=1)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X = df.iloc[:,0:4]
Y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=42, test_size=0.2)

X_train.shape, y_train.shape
# Out:
# ((120, 4), (120,))

# %%
gbrt = GradientBoostingClassifier(n_estimators=3, max_depth=2, learning_rate=0.1)
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=2, n_estimators=3)

# %%
y_pred = gbrt.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %% [markdown]
# # Results (n_estimators=3, max_depth=2, learning_rate=0.1)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# # Results (n_estimators=3, max_depth=1, learning_rate=0.1)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Results (n_estimators=3, max_depth=1, learning_rate=1.0)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
