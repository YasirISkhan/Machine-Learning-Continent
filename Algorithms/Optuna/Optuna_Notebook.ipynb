# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.7 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 18.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0

# %%
import optuna
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df = pd.read_csv(url, names=columns)

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
cols_with_missing_vals = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
df[cols_with_missing_vals] = df[cols_with_missing_vals].replace(0, np.nan)

df.fillna(df.mean(), inplace=True)

print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = df.drop(columns='Outcome', axis=1)
y =df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(f'Training set shape: {X_train.shape}')
print(f'Test set shape: {X_test.shape}')
# Out:
# Training set shape: (537, 8)
# Test set shape: (231, 8)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# define the objective function
def objective(trail):
  # suggest
  n_estimators = trail.suggest_int('n_estimators', 50, 200)
  max_depth = trail.suggest_int('max_depth', 3, 20)

  # create the RandomforestClassifier with suggested hyperparameters
  model = RandomForestClassifier(
      n_estimators=n_estimators,
      max_depth=max_depth,
      random_state=42
  )

  # Perform 3-fold cross_validation and calculate accuracy
  score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
  # return the accuracy score for optuna to maximize
  return score

# %%
# create a study object and optimize the objective function
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())
# run 50 trials to find the best hyperparameters
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-06-08 04:17:53,291] A new study created in memory with name: no-name-1befc66a-7d4c-4467-991c-b9c3239e6c01
# [I 2025-06-08 04:17:53,997] Trial 0 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 73, 'max_depth': 9}. Best is trial 0 with value: 0.7672253258845437.
# [I 2025-06-08 04:17:55,469] Trial 1 finished with value: 0.7802607076350093 and parameters: {'n_estimators': 133, 'max_depth': 7}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:17:57,174] Trial 2 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 200, 'max_depth': 15}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:17:57,482] Trial 3 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 50, 'max_depth': 16}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:17:58,182] Trial 4 finished with value: 0.7560521415270017 and parameters: {'n_estimators': 133, 'max_depth': 3}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:17:59,412] Trial 5 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 144, 'max_depth': 20}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:00,816] Trial 6 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 174, 'max_depth': 10}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:01,857] Trial 7 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 117, 'max_depth': 14}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:02,458] Trial 8 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 59, 'max_depth': 12}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:02,828] Trial 9 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 59, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:03,433] Trial 10 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 103, 'max_depth': 5}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:04,568] Trial 11 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 200, 'max_depth': 7}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:05,516] Trial 12 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 159, 'max_depth': 16}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:06,457] Trial 13 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 156, 'max_depth': 17}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:07,479] Trial 14 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 165, 'max_depth': 12}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:08,001] Trial 15 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 90, 'max_depth': 7}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:08,735] Trial 16 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 123, 'max_depth': 8}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:09,796] Trial 17 finished with value: 0.7746741154562383 and parameters: {'n_estimators': 180, 'max_depth': 13}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:10,672] Trial 18 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 145, 'max_depth': 18}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:11,281] Trial 19 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 108, 'max_depth': 5}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:12,080] Trial 20 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 135, 'max_depth': 10}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:13,528] Trial 21 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 180, 'max_depth': 14}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:15,230] Trial 22 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 187, 'max_depth': 15}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:16,174] Trial 23 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 156, 'max_depth': 17}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:17,175] Trial 24 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 167, 'max_depth': 14}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:18,275] Trial 25 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 187, 'max_depth': 10}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:19,210] Trial 26 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 154, 'max_depth': 13}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:19,989] Trial 27 finished with value: 0.7579143389199254 and parameters: {'n_estimators': 140, 'max_depth': 3}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:20,973] Trial 28 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 166, 'max_depth': 11}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:21,539] Trial 29 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 93, 'max_depth': 16}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:22,262] Trial 30 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 128, 'max_depth': 5}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:23,390] Trial 31 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 190, 'max_depth': 14}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:24,455] Trial 32 finished with value: 0.7746741154562383 and parameters: {'n_estimators': 180, 'max_depth': 13}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:25,618] Trial 33 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 173, 'max_depth': 15}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:27,004] Trial 34 finished with value: 0.7765363128491621 and parameters: {'n_estimators': 153, 'max_depth': 16}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:28,259] Trial 35 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 149, 'max_depth': 17}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:29,222] Trial 36 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 160, 'max_depth': 20}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:30,116] Trial 37 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 149, 'max_depth': 16}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:30,941] Trial 38 finished with value: 0.7765363128491619 and parameters: {'n_estimators': 135, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:31,647] Trial 39 finished with value: 0.7765363128491621 and parameters: {'n_estimators': 115, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:32,325] Trial 40 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 113, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:33,029] Trial 41 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 117, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:33,718] Trial 42 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 112, 'max_depth': 19}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:34,464] Trial 43 finished with value: 0.7802607076350093 and parameters: {'n_estimators': 123, 'max_depth': 18}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:35,050] Trial 44 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 97, 'max_depth': 18}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:35,571] Trial 45 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 83, 'max_depth': 20}. Best is trial 1 with value: 0.7802607076350093.
# [I 2025-06-08 04:18:36,311] Trial 46 finished with value: 0.7821229050279329 and parameters: {'n_estimators': 124, 'max_depth': 18}. Best is trial 46 with value: 0.7821229050279329.
# [I 2025-06-08 04:18:37,073] Trial 47 finished with value: 0.7821229050279329 and parameters: {'n_estimators': 124, 'max_depth': 18}. Best is trial 46 with value: 0.7821229050279329.
# [I 2025-06-08 04:18:37,824] Trial 48 finished with value: 0.7821229050279329 and parameters: {'n_estimators': 124, 'max_depth': 18}. Best is trial 46 with value: 0.7821229050279329.
# [I 2025-06-08 04:18:38,927] Trial 49 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 126, 'max_depth': 18}. Best is trial 46 with value: 0.7821229050279329.

# %%
print(f'Bets trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Bets trial accuracy: 0.7821229050279329
# Best hyperparameters: {'n_estimators': 124, 'max_depth': 18}

# %%
from sklearn.metrics import accuracy_score
best_model = RandomForestClassifier(**study.best_trial.params, random_state=42)

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

test_accuracy = accuracy_score(y_test, y_pred)
print(f'Test accuracy with best hyperparameters: {test_accuracy: .2f}')
# Out:
# Test accuracy with best hyperparameters:  0.74

# %% [markdown]
# # Best Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# %%
# Define the objective function for Optuna
def objective(trial):
    # Choose the algorithm to tune
    classifier_name = trial.suggest_categorical('classifier', ['SVM', 'RandomForest', 'GradientBoosting'])

    if classifier_name == 'SVM':
        # SVM hyperparameters
        c = trial.suggest_float('C', 0.1, 100, log=True)
        kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'sigmoid'])
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])

        model = SVC(C=c, kernel=kernel, gamma=gamma, random_state=42)

    elif classifier_name == 'RandomForest':
        # Random Forest hyperparameters
        n_estimators = trial.suggest_int('n_estimators', 50, 300)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
        bootstrap = trial.suggest_categorical('bootstrap', [True, False])

        model = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            bootstrap=bootstrap,
            random_state=42
        )

    elif classifier_name == 'GradientBoosting':
        # Gradient Boosting hyperparameters
        n_estimators = trial.suggest_int('n_estimators', 50, 300)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log=True)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)

        model = GradientBoostingClassifier(
            n_estimators=n_estimators,
            learning_rate=learning_rate,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42
        )

    # Perform cross-validation and return the mean accuracy
    score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
    return score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-06-08 05:51:26,781] A new study created in memory with name: no-name-358d4d8d-63bc-4a9b-a488-a8fbaf6edcea
# [I 2025-06-08 05:51:26,912] Trial 0 finished with value: 0.7709497206703911 and parameters: {'classifier': 'SVM', 'C': 0.6935284540858504, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.7709497206703911.
# [I 2025-06-08 05:51:26,996] Trial 1 finished with value: 0.7690875232774674 and parameters: {'classifier': 'SVM', 'C': 0.5919707235190612, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.7709497206703911.
# [I 2025-06-08 05:51:27,084] Trial 2 finished with value: 0.7653631284916201 and parameters: {'classifier': 'SVM', 'C': 1.297765503428147, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.7709497206703911.
# [I 2025-06-08 05:51:27,158] Trial 3 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.20300046060009772, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:30,491] Trial 4 finished with value: 0.7541899441340782 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 131, 'learning_rate': 0.011962573313415355, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:30,589] Trial 5 finished with value: 0.739292364990689 and parameters: {'classifier': 'SVM', 'C': 0.11504905556435256, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:30,673] Trial 6 finished with value: 0.6871508379888268 and parameters: {'classifier': 'SVM', 'C': 31.776784262742826, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:30,739] Trial 7 finished with value: 0.750465549348231 and parameters: {'classifier': 'SVM', 'C': 0.6413525414904118, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:33,933] Trial 8 finished with value: 0.7299813780260708 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 142, 'learning_rate': 0.10250102569163072, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:35,386] Trial 9 finished with value: 0.7597765363128491 and parameters: {'classifier': 'RandomForest', 'n_estimators': 123, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': True}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:38,197] Trial 10 finished with value: 0.750465549348231 and parameters: {'classifier': 'RandomForest', 'n_estimators': 284, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 3 with value: 0.7858472998137803.
# [I 2025-06-08 05:51:38,336] Trial 11 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.12465198557281104, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:51:38,448] Trial 12 finished with value: 0.7877094972067038 and parameters: {'classifier': 'SVM', 'C': 0.10102391974411093, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:51:38,716] Trial 13 finished with value: 0.7858472998137801 and parameters: {'classifier': 'SVM', 'C':
 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:14,750] Trial 64 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.2820602098878016, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:14,807] Trial 65 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.14153754173721655, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,346] Trial 66 finished with value: 0.7709497206703911 and parameters: {'classifier': 'RandomForest', 'n_estimators': 94, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 8, 'bootstrap': False}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,409] Trial 67 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.21337489865071618, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,464] Trial 68 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.74012218729404, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,501] Trial 69 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.13981444019755668, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,542] Trial 70 finished with value: 0.7839851024208566 and parameters: {'classifier': 'SVM', 'C': 0.541573304580163, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,590] Trial 71 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.13199110890523263, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,633] Trial 72 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.12984078096243815, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,669] Trial 73 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.20471300090221733, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,704] Trial 74 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.12895257396565243, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,745] Trial 75 finished with value: 0.7281191806331471 and parameters: {'classifier': 'SVM', 'C': 0.31341053818647713, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:15,787] Trial 76 finished with value: 0.7877094972067038 and parameters: {'classifier': 'SVM', 'C': 0.1848767045501437, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:21,114] Trial 77 finished with value: 0.7448789571694601 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 269, 'learning_rate': 0.11276623514695003, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:21,174] Trial 78 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.24908676599487412, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:21,265] Trial 79 finished with value: 0.7858472998137801 and parameters: {'classifier': 'SVM', 'C': 4.637258784200772, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:22,209] Trial 80 finished with value: 0.7579143389199255 and parameters: {'classifier': 'RandomForest', 'n_estimators': 92, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 6, 'bootstrap': True}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:22,267] Trial 81 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.1317891879194556, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:22,324] Trial 82 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.1403317257539766, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:22,379] Trial 83 finished with value: 0.7877094972067038 and parameters: {'classifier': 'SVM', 'C': 0.18426004412461502, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,292] Trial 84 finished with value: 0.7858472998137801 and parameters: {'classifier': 'SVM', 'C': 99.1245531468459, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,349] Trial 85 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.11907237521414946, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,428] Trial 86 finished with value: 0.7728119180633147 and parameters: {'classifier': 'SVM', 'C': 0.17487633972133293, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,501] Trial 87 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.2514185571218176, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,613] Trial 88 finished with value: 0.7169459962756052 and parameters: {'classifier': 'SVM', 'C': 54.708999871265135, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,671] Trial 89 finished with value: 0.7821229050279329 and parameters: {'classifier': 'SVM', 'C': 0.37996925581035784, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,730] Trial 90 finished with value: 0.7877094972067038 and parameters: {'classifier': 'SVM', 'C': 0.10171317709728238, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,793] Trial 91 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.14693181539780048, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,865] Trial 92 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.15082477151762444, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:23,927] Trial 93 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.12619328441920402, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:24,011] Trial 94 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.19130256499778167, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:24,090] Trial 95 finished with value: 0.7150837988826816 and parameters: {'classifier': 'SVM', 'C': 0.15434502811354758, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:25,587] Trial 96 finished with value: 0.750465549348231 and parameters: {'classifier': 'GradientBoosting', 'n_estimators': 165, 'learning_rate': 0.14906941941041812, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 9}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:25,631] Trial 97 finished with value: 0.7895716945996275 and parameters: {'classifier': 'SVM', 'C': 0.12103854879875652, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:25,682] Trial 98 finished with value: 0.7858472998137803 and parameters: {'classifier': 'SVM', 'C': 0.23684368772252568, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 11 with value: 0.7895716945996275.
# [I 2025-06-08 05:52:26,850] Trial 99 finished with value: 0.7653631284916201 and parameters: {'classifier': 'RandomForest', 'n_estimators': 193, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 11 with value: 0.7895716945996275.

# %%
best_trials = study.best_trial
print(f'Best trial parameters: ', best_trials.params)
print(f'Best trial accuracy: {best_trials.value}')
# Out:
# Best trial parameters:  {'classifier': 'SVM', 'C': 0.12465198557281104, 'kernel': 'linear', 'gamma': 'scale'}
# Best trial accuracy: 0.7895716945996275

# %%
study.trials_dataframe()
# Out:
#     number     value  ... params_n_estimators     state
# 0        0  0.770950  ...                 NaN  COMPLETE
# 1        1  0.769088  ...                 NaN  COMPLETE
# 2        2  0.765363  ...                 NaN  COMPLETE
# 3        3  0.785847  ...                 NaN  COMPLETE
# 4        4  0.754190  ...               131.0  COMPLETE
# ..     ...       ...  ...                 ...       ...
# 95      95  0.715084  ...                 NaN  COMPLETE
# 96      96  0.750466  ...               165.0  COMPLETE
# 97      97  0.789572  ...                 NaN  COMPLETE
# 98      98  0.785847  ...                 NaN  COMPLETE
# 99      99  0.765363  ...               193.0  COMPLETE
#
# [100 rows x 16 columns]

# %%
study.trials_dataframe()['params_classifier'].value_counts()
# Out:
# params_classifier
# SVM                 80
# GradientBoosting    10
# RandomForest        10
# Name: count, dtype: int64

# %%
study.trials_dataframe().groupby('params_classifier')['value'].mean()
# Out:
# params_classifier
# GradientBoosting    0.741527
# RandomForest        0.761825
# SVM                 0.774604
# Name: value, dtype: float64
