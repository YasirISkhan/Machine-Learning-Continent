# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv', names=['times_pregnant','plasma_glucose_concentration','Diastolic_blood_pressure','Triceps_skinfold_thickness','serum_insulin','body_mass_index','Diabetes_pedigree_function','Age','Class'])

# %%
print(data.shape)
data.sample(5)
# Out:
# (768, 9)
#      times_pregnant  plasma_glucose_concentration  Diastolic_blood_pressure  \
# 48                7                           103                        66
# 496               5                           110                        68
# 57                0                           100                        88
# 676               9                           156                        86
# 283               7                           161                        86
#
#      Triceps_skinfold_thickness  serum_insulin  body_mass_index  \
# 48                           32              0             39.1
# 496                           0              0             26.0
# 57                           60            110             46.8
# 676                           0              0             24.8
# 283                           0              0             30.4
#
#      Diabetes_pedigree_function  Age  Class
# 48                        0.344   31      1
# ...

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
X = data.iloc[:,:8]
Y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=1, test_size=0.2)

X_train.shape, X_test.shape
# Out:
# ((614, 8), (154, 8))

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6883116883116883

# %% [markdown]
# # Hyperparameter Tuning

# %%
param_dist = {
    'criterion': ['gini','entropy','log_loss'],
    'max_depth': [1,2,3,4,5,7,8,9,None],
    'splitter': ['best','random'],
    'min_samples_split': [1,2,3,4,5,6,7],
    'max_features': [1,2,3,4,5,6,7,'sqrt','log2',None],
    'min_impurity_decrease': [0.1,0.01,0.02]
}

# %%
grid = GridSearchCV(clf, param_dist, cv=10, n_jobs=-1)

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 16200 fits failed out of a total of 113400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 16200 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\yasir\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'max_features': 4,
#  'min_impurity_decrease': 0.01,
#  'min_samples_split': 7,
#  'splitter': 'best'}

# %%
grid.best_score_
# Out:
# 0.7557112638815441
