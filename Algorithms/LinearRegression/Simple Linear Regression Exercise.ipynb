# %% [markdown]
# # Simple linear regression - exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size.csv'.
#
# You are expected to create a simple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables is 'size'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('real_estate_price_size.csv')

# %%
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
data.shape
# Out:
# (100, 2)

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
X = data.drop(columns=['price'])
Y = data['price']

# %%
# Creating training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=2, test_size=0.2)

X_train.shape, X_test.shape
# Out:
# ((80, 1), (20, 1))

# %% [markdown]
# ### Explore the data

# %%
sns.scatterplot(data=data, x=data['size'], y=data['price'])
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %% [markdown]
# ### Regression itself

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([243559.92766424, 327616.3807911 , 332590.09478317, 216716.0630996 ,
#        254420.61468327, 215015.43286669, 207899.33677772, 401723.11706407,
#        252253.05501899, 327369.18285684, 257796.69758171, 255331.58484841,
#        367243.58297456, 394137.80267396, 243559.92766424, 222181.88409042,
#        440782.67954664, 438862.31781661, 256242.55501355, 368424.63977157])

# %%
y_test.head()
# Out:
# 83    282683.544
# 30    301635.728
# 56    320345.520
# 24    168047.264
# 16    248337.600
# Name: price, dtype: float64

# %% [markdown]
# ### Plot the regression line on the initial scatter

# %%
sns.scatterplot(data=data, x=data['size'], y=data['price'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.show()
